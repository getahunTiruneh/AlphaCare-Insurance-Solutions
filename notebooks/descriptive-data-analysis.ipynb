# %%
import sys
import os
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Append the parent directory to sys.path
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# ignore warrnings
import warnings
warnings.filterwarnings("ignore")

# %%
from scripts.Insurance_EDA import InsuranceEDA

# %%
file = '../data/MachineLearningRating_v3.txt'
df=pd.read_csv(file, delimiter='|')

# %%
df
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
# ...

# %%
# Initialize EDA class with the dataset file path
eda = InsuranceEDA(df)

# %% [markdown]
# ### Data Summarization

# %% [markdown]
# ##### Descriptive Statistics

# %%
eda.summarize_data(df)
# Out:
# Data Summary:
#         UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %% [markdown]
# ##### Data Structure:

# %% [markdown]
# ### Data Quality Assessment

# %%
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %%
data_plot=DataVisualizer(df)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %% [markdown]
# ### Univariate Analysis

# %%
eda.plot_univariate_analysis(df,numerical_cols,categorical_cols)
# Out:
# Failed to interrupt the Kernel.
#
# Unable to start Kernel '.venv (Python 3.12.6)' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Bivariate & Multivariate Analysis

# %%
eda.plot_bivariate_analysis(df, 'TotalPremium', 'TotalClaims', 'PostalCode')

# %% [markdown]
# ### Data Comparison

# %% [markdown]
# ### Outlier Detection

# %% [markdown]
# ### Visualization

# %% [markdown]
# dv=DataVisualizer(df)

# %%
dv=DataVisualizer(df)

# %%
dv.create_creative_plots()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dv.create_creative_plots()
#
# File e:\Kiffya_10_acc\Week 3\AlphaCare-Insurance-Solutions\src\visualization.py:85, in DataVisualizer.create_creative_plots(df)
#      83 # Example: Scatter plot with regression line
#      84 plt.figure(figsize=(10, 8))
# ---> 85 sns.regplot(x='SumInsured', y='CalculatedPremiumPerTerm', data=df, scatter_kws={'s':10}, line_kws={'color':'red'})
#      86 plt.title('SumInsured vs CalculatedPremiumPerTerm')
#      87 plt.show()
#
# ...
